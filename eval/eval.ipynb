# %%
import sys
sys.path.append('..')

# 모델 예측값과 y 레이블의 정답값 분포 시각화
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from cleansing.data_cleansing import preprocess_data
from model.models import LGBMmodel

_, _, _, y_test = preprocess_data()

predictions = LGBMmodel()

# 예측값과 실제값의 분포 시각화
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Actual vs Predicted')

# y_test 히스토그램
axs[0].hist(y_test, bins=30, alpha=0.5, color='blue', label='Actual')
axs[0].set_xlabel('Damage Scale')
axs[0].set_ylabel('Frequency')

# lr_pred, ridge_pred, lasso_pred, enet_pred, dt_pred, rf_pred
# y_pred_lgb 히스토그램
axs[1].hist(predictions, bins=30, alpha=0.5, color='red', label='Predicted')
axs[1].set_xlabel('Damage Scale')
axs[1].set_ylabel('Frequency')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/matmang/Documents/GitHub/bool-bird-project/eval/eval.ipynb 셀 1 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/Users/matmang/Documents/GitHub/bool-bird-project/eval/eval.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/matmang/Documents/GitHub/bool-bird-project/eval/eval.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> from cleansing.data_cleansing import preprocess_data
# ----> <a href='vscode-notebook-cell:/Users/matmang/Documents/GitHub/bool-bird-project/eval/eval.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> from model.models import LGBMmodel
#      <a href='vscode-notebook-cell:/Users/matmang/Documents/GitHub/bool-bird-project/eval/eval.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> _, _, _, y_test = preprocess_data()
#      <a href='vscode-notebook-cell:/Users/matmang/Documents/GitHub/bool-bird-project/eval/eval.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a> predictions = LGBMmodel()
#
# File ~/Documents/GitHub/bool-bird-project/eval/../model/models.py:19, in <module>
#      16 from sklearn.svm import SVR
#      17 import numpy as np
# ---> 19 X_train, X_test, y_train, y_test = preprocess_data()
#      21 def LGBMmodel():
#      22     # LightGBM 데이터셋으로 변환
#      23     lgb_train = lgb.Dataset(X_train, label=y_train)
#
# File ~/Documents/GitHub/bool-bird-project/eval/../cleansing/data_cleansing.py:35, in preprocess_data()
#      33 df['발생일시'] = df['발생일시'].apply(extract_month)
#      34 df['시설물 종류'] = df['시설물 종류'].apply(extract_facility)
# ---> 35 df['공사기간'] = df['공사기간'].apply(count_days)
#      36 df['공정률'] = df['공정률'].apply(str_to_median)
#      37 df['작업자수'] = df['작업자수'].apply(extract_population)
#
# File ~/opt/anaconda3/envs/bert-study/lib/python3.10/site-packages/pandas/core/series.py:4774, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4664 def apply(
#    4665     self,
#    4666     func: AggFuncType,
#    (...)
#    4669     **kwargs,
#    4670 ) -> DataFrame | Series:
#    4671     """
#    4672     Invoke function on values of Series.
#    4673
#    (...)
#    4772     dtype: float64
#    4773     """
# -> 4774     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/envs/bert-study/lib/python3.10/site-packages/pandas/core/apply.py:1100, in SeriesApply.apply(self)
#    1097     return self.apply_str()
#    1099 # self.f is Callable
# -> 1100 return self.apply_standard()
#
# File ~/opt/anaconda3/envs/bert-study/lib/python3.10/site-packages/pandas/core/apply.py:1151, in SeriesApply.apply_standard(self)
#    1149     else:
#    1150         values = obj.astype(object)._values
# -> 1151         mapped = lib.map_infer(
#    1152             values,
#    1153             f,
#    1154             convert=self.convert_dtype,
#    1155         )
#    1157 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1158     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1159     #  See also GH#25959 regarding EA support
#    1160     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/envs/bert-study/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2919, in pandas._libs.lib.map_infer()
#
# File ~/Documents/GitHub/bool-bird-project/eval/../util/preprocessing.py:132, in count_days(date_string)
#     130 start_date = parser.parse(start_date_str)
#     131 end_date = parser.parse(end_date_str)
# --> 132 if (end_date - start_date).days <= 0:
#     133     sub_date = date_string.split('(해당공종 :')[1].strip()
#     134     sub_date_str = sub_date.split(')')[0].strip()
#
# TypeError: can't subtract offset-naive and offset-aware datetimes

# %%
fig, ax = plt.subplots()
ax.hist(y_test, bins=30, alpha=0.5, color='blue', label='Actual')
ax.hist(predictions, bins=30, alpha=0.5, color='red', label='Predicted')
ax.set_xlabel('Damage Scale')
ax.set_ylabel('Frequency')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# 예측값과 실제값 비교
plt.figure(figsize=(8, 8))
plt.scatter(y_test, predictions, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [predictions.min(), predictions.max()], 'k--', lw=4)
plt.xlabel('True Value')
plt.ylabel('Prediction')
plt.show()
