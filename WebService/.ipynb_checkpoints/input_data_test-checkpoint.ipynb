# %%
import sys
sys.path.append('..')
# from predict.predict import predict 

import pandas as pd
from dateutil import parser

list = ["시설물 종류_건축","시설물 종류_산업환경설비","시설물 종류_조경","시설물 종류_토목",
        "공공/민간 구분_공공","공공/민간 구분_민간",
        "날씨_강설","날씨_강우","날씨_강풍","날씨_맑음","날씨_안개","날씨_흐림",
        "공종_가설공사","공종_강구조물공사","공종_건축 토공사","공종_건축물 부대공사","공종_관공사","공종_관공사 부대공사","공종_교량공사","공종_금속공사","공종_기계설비공사","공종_기타","공종_댐 및 제방공사","공종_도로 및 포장공사","공종_도장공사","공종_말뚝공사","공종_목공사","공종_미장공사","공종_방수공사","공종_산업설비공사","공종_수장공사","공종_전기설비공사","공종_조경공사","공종_조적공사","공종_지반개량공사","공종_지반조사","공종_지붕 및 홈통공사","공종_지정공사","공종_창호 및 유리공사","공종_철골공사","공종_철근콘크리트공사","공종_철도 및 궤도공사","공종_타일 및 돌공사","공종_터널공사","공종_토공사","공종_통신설비공사","공종_특수 건축물공사","공종_프리캐스트 콘크리트공사","공종_하천공사","공종_항만공사","공종_해체 및 철거공사",
        "발생일시","공사비","공사기간","공정률","작업자수","설계안전성검토","기온","습도"]

df = pd.DataFrame({"class": list, "boolean": 0.0})
df =df.set_index("class")

#(1) 공사기간 (yy.mm.dd ~ yy.mm.dd)
start_day = '2020-06-01'
end_day = '2020-08-01'

#(2) 공사기간 계산
start_day = parser.parse(start_day)
end_day = parser.parse(end_day)
dur = (end_day - start_day).days
df.loc['공사기간'] = dur

#(3) 시설물종류 (건축~)
string = '시설물 종류_'
selected_facility = '건축'
df.loc[string + selected_facility] = 1.0
    
#(4) 공정률 (~%)
percent = 65
if percent:
    df.loc['공정률'] = float(percent)
else:
    df.loc['공정률'] = None 
    
#(6),(5) 공종 (철근콘크리트~)
selected_category = '가설공사'
string = '공종_'
df.loc[string + selected_category] = 1.0

#(7) 설계안전성검토 (대상,비대상)
selected_safety = "대상"
if (selected_safety == "대상"):
    df.loc['설계안전성검토'] = 1.0

#(8) 시설관리공사 (공공,민간)
selected_company = "공공"
if (selected_company == "공공"):
    df.loc['시설관리공사'] = 1.0

#(9) 공사비 (~원)
cost = 10
df.loc['공사비'] = float(cost)

#(10) 작업자수 (~명)
person = 1000
df.loc['작업자수'] = float(person)

#(11, 12, 13) 날씨, 기온, 습도 -> 따로 입력X

# 기상청 데이터 연결 "기상청_단기예보 ((구)_동네예보) 조회서비스"
import requests
import xml.etree.ElementTree as ET
from datetime import datetime
string = '날씨_'
key = '맑음'

# API 요청 URL
url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getUltraSrtNcst'

# 인증키
api_key = 'NminqLTNuSX5OFbyRamiOBFhuUBormib7/IeKYFKpWn1iXnxa1PEQ5IZAfJWebf8nOOb2FplMo5tdutaV6kUxQ=='

# 현재 날짜와 시간 가져오기
now = datetime.now()
date = now.strftime('%Y%m%d')  # 날짜 형식 변환
time = now.strftime('%H')+'00' # 시간 형식 변환  --> 여기서 오류, 10분 미만일 때 API 못불러옴

# # 사용자로부터 날짜와 시간 입력받기
# date = input('날짜를 입력하세요 (예: 20230608): ')
# time = input('시간을 입력하세요 (예: 1400): ')

# 요청 파라미터
params = {
    'serviceKey': api_key,
    'numOfRows': '10',  # 가져올 데이터 개수
    'dataType': 'XML',  # 응답 데이터 형식
    'base_date': date,  # 기준 날짜
    'base_time': time,  # 기준 시간
    'nx': '60',  # 위도
    'ny': '127'  # 경도
}

# API 요청 보내기
response = requests.get(url, params=params)
if (response.status_code != 200):
    params['base_time'] = '0000'
    response = requests.get(url, params=params)
xml_data = response.text

# XML 파싱
tree = ET.ElementTree(ET.fromstring(xml_data))
root = tree.getroot()

# 필요한 데이터 추출
items = root.findall('.//item')

found = False

for item in items:
    category = item.find('category').text
    if category == 'T1H':  # 기온(category=T1H) 데이터 추출
        temp = item.find('obsrValue').text
        found = True
    elif category == 'REH':  # 습도(category=REH) 데이터 추출
        humidity = item.find('obsrValue').text
        found = True
    elif category == "SKY": # 맑음=1, 흐림=4
        sky = item.find('obsrValue').text
        if sky == '4':
            key = '흐림'
        found = True
    elif category == "PTY": # 강설=3, 강우=1
        pty = item.find('obsrValue').text
        if pty == '3': 
            key = '강설'
        elif pty == '1':
            key = '강우'
        found = True
    elif category == "WSD": # 강풍>=9
        wsd = item.find('obsrValue').text 
        wsd = int(float(wsd))
        if wsd >= 9: 
            key = '강풍'
        found = True

print(df)
# print(predict(df))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/2x/6y58jvbx1bq0q1gn8gtc98w40000gn/T/ipykernel_12830/2290106494.py in <module>
#       1 import sys
#       2 sys.path.append('..')
# ----> 3 from predict.predict import predict
#       4
#       5 import pandas as pd
#
# ~/Git/accident-data/WebService/../predict/predict.py in <module>
#       2 sys.path.append('..')
#       3
# ----> 4 from model.models import LGBMmodel, LGBMmodel_classification
#       5 import numpy as np
#       6
#
# ~/Git/accident-data/WebService/../model/models.py in <module>
#       2 sys.path.append('..')
#       3
# ----> 4 import lightgbm as lgb
#       5 from sklearn.metrics import mean_squared_error
#       6 import matplotlib.pyplot as plt
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/__init__.py in <module>
#       6 from pathlib import Path
#       7
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, print_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py in <module>
#     108
#     109
# --> 110 _LIB = _load_lib()
#     111
#     112
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py in _load_lib()
#      99     if len(lib_path) == 0:
#     100         return None
# --> 101     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     102     lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     103     callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py in LoadLibrary(self, name)
#     458
#     459     def LoadLibrary(self, name):
# --> 460         return self._dlltype(name)
#     461
#     462     __class_getitem__ = classmethod(_types.GenericAlias)
#
# ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     380
#     381         if handle is None:
# --> 382             self._handle = _dlopen(self._name, mode)
#     383         else:
#     384             self._handle = handle
#
# OSError: dlopen(/Users/soyeon/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/soyeon/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)

# %%
# !brew install libomp
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# aarch64-elf-gdb                          llvm@15
# access                                   lowdown
# ada-url                                  lpeg
# adr-viewer                               luacheck
# aftman                                   m1ddc
# aichat                                   macpine
# aicommits                                mariadb@10.10
# aiven-client                             mariadb@10.11
# akku                                     mariadb@10.8
# aliyunpan                                mariadb@10.9
# amber                                    markdownlint-cli2
# ancient                                  marksman
# animdl                                   mdless
# ansible@6                                mdt
# ansible@7                                melange
# apko                                     meta-package-manager
# aptos                                    metals
# ares                                     micromamba
# argparse                                 millet
# aribb24                                  mimirtool
# arjun                                    mods
# arttime                                  mpfrcx
# ast-grep                                 muon
# astgen                                   musikcube
# ata                                      naga-cli
# aws-amplify                              nap
# aws-sam-cli                              nemu
# aws-sso-cli                              nerdfix
# base16384                                nexttrace
# bashate                                  nixpacks
# benerator                                node@18
# bindgen                                  notify
# blocky                                   ntfy
# boolector                                oauth2c
# bossa                                    ocm
# brpc                                     ocmtoc
# btrfs-progs                              octobuild
# buf                                      okta-aws-cli
# busted                                   okta-awscli
# bwidget                                  ol
# bzip3                                    opal
# cargo-about                              openai-whisper
# cargo-deny                               opencl-clhpp-headers
# cargo-make                               openfga
# cargo-release                            openiked
# cascadia                                 openssl@3.0
# cdebug                                   openvino
# cdsclient                                osv-scanner
# cffi                                     pandemics
# chatblade                                papilo
# check-jsonschema                         pari-nflistdata
# clang-build-analyzer                     pbzx
# clifm                                    pdf-diff
# clipboard                                pferd
# clitest                                  pfetch-rs
# clive                                    pgvector
# cloudflare-wrangler2                     phoneinfoga
# cloudpan189-go                           php@8.1
# cloudprober                              picotool
# clusterawsadm                            pinocchio
# cmctl                                    pipdeptree
# cntb                                     pluto
# cocogitto                                plz-cli
# code-cli                                 pmtiles
# cog                                      pocketbase
# conan@1                                  podsync
# conda-zsh-completion                     poke
# conduit                                  pomsky
# conman                                   portablegl
# convco                                   portal
# copa                                     procps@3
# core-lightning                           protobuf@21
# corrosion                                protolint
# countdown                                prowler
# cpuid                                    proxsuite
# crfsuite                                 prs
# d2                                       psysh
# ddns-go                                  pycparser
# debugbreak                               pygit2
# define                                   python-gdbm@3.11
# devcontainer                             python-lsp-server
# dexter                                   python-tk@3.11
# dotnet@6                                 python@3.11
# dstack                                   qdmr
# dtools                                   quantum++
# dufs                                     quartz-wm
# dutree                                   renovate
# dzr                                      resvg
# ecoji                                    retdec
# elfx86exts                               rnr
# emqx                                     roblox-ts
# enchive                                  rojo
# enpass-cli                               rtx
# envd                                     ruby@3.1
# erdtree                                  ruff
# erigon                                   rye
# evtx                                     sad
# fastgron                                 safeint
# ffmpeg@5                                 sapling
# fgbio                                    scip
# flagd                                    scriptisto
# flavours                                 secp256k1
# forgit                                   service-weaver
# form                                     seven-kingdoms
# garble                                   shodan
# gat                                      simdutf
# gcc@12                                   sing-box
# geometry                                 skaffold@1.39
# gf                                       skeema
# gfold                                    smartdns
# ghc@9.2                                  snakefmt
# git-big-picture                          sniffnet
# git-credential-oauth                     socket_vmnet
# git-tools                                solhint
# gitoxide                                 soplex
# gmssl                                    souffle
# go-feature-flag-relay-proxy              spectral-cli
# go-task                                  speedbump
# go@1.19                                  spek
# gobackup                                 spotify_player
# gokey                                    sql-language-server
# golines                                  sql-migrate
# gradle@7                                 ssocr
# grammarly-languageserver                 stackql
# grantlee                                 standard
# graphqxl                                 staq
# grayskull                                steampipe
# grpc@1.54                                stepci
# guile-gnutls                             streamvbyte
# gyb                                      stuffbin
# hck                                      stylelint
# hermit                                   svlint
# hexer                                    svls
# hotbuild                                 swift-outdated
# hq                                       syft
# httm                                     symlinks
# huggingface-cli                          syslog-ng
# hysteria                                 tailwindcss-language-server
# hz                                       tart
# ibazel                                   teip
# imessage-exporter                        temporal
# ipget                                    tern
# jbang                                    tetra
# jet                                      thriftgo
# joern                                    tkey-ssh-agent
# johnnydep                                tl-expected
# joker                                    totp-cli
# joshuto                                  touca
# jreleaser                                tproxy
# jscpd                                    tracy
# jsign                                    trippy
# juicefs                                  trurl
# keploy                                   trust-dns
# keyring                                  tt
# kitex                                    tut
# ksops                                    twm
# kubefirst                                txt2man
# kubent                                   typescript-language-server
# kubevious                                typos-cli
# kustomizer                               typst
# kuttl                                    ulfius
# kwctl                                    unxip
# kwok                                     utftex
# lacework-cli                             uvg266
# leetup                                   valijson
# lemmeknow                                vhs
# libabigail                               victoriametrics
# libansilove                              video-compare
# libaribcaption                           virtualfish
# libclc                                   votca
# libdivide                                vscode-langservers-extracted
# libdvbcsa                                vulkan-extensionlayer
# libecpint                                vulkan-tools
# libemf2svg                               vulkan-validationlayers
# libfastjson                              vvdec
# libfyaml                                 vvenc
# libgedit-gtksourceview                   wally
# libgit2@1.5                              waybackpy
# libgrapheme                              wazero
# libint                                   wikibase-cli
# libisofs                                 wpebackend-fdo
# liblerc                                  wxlua
# liblxi                                   wzprof
# libmediainfo                             xbyak
# libomemo-c                               xcdiff
# libpaho-mqtt                             xcodes
# libpaper                                 xinit
# libsais                                  xmodmap
# libsolv                                  xorg-server
# libunibreak                              xrdb
# libvisual                                xurls
# libvisual-plugins                        yamlfmt
# libvisual-projectm                       youplot
# libwpe                                   zf
# libzen                                   zlint
# libzim                                   zls
# license-eye                              zpaqfranz
# licensed                                 zsh-autocomplete
# llama                                    zsh-autopair
# ==> New Casks
# 115
# 1kc-razer
# 86box
# active-trader-pro
# adze
# agi
# alex313031-thorium
# alipay-key-tool
# ankerslicer
# ankerwork
# anytype
# apple-hewlett-packard-printer-drivers
# archaeology
# asix-ax88179
# attachecase
# bambu-studio
# bazecor
# beardie
# binocs
# bloop
# bluos-controller
# blurscreen
# bookletcreator
# bose-updater
# bruno
# buzz
# cad-assistant
# caldigit-docking-utility
# caldigit-thunderbolt-charging
# calhash
# cameracontroller
# canon-eos-utility
# capacities
# capslocknodelay
# carbide-create
# chatbox
# clickshare
# codeedit
# codux
# coherence-x
# color-studio
# concept2-utility
# confectionery
# copilot
# copilot-for-xcode
# corsair-icue
# craft
# creative
# cursor
# cursr
# dadroit-json-viewer
# dbeaverlite
# dbeaverultimate
# ddpm
# dehelper
# devpod
# devsquadron
# dintch
# displaylink
# doppler
# droidcam-obs
# duplicacy-cli
# dymo-label
# easydict
# edrawmind
# egnyte
# elephas
# elgato-camera-hub
# elgato-control-center
# elgato-game-capture-hd
# elgato-stream-deck
# elgato-video-capture
# elgato-wave-link
# elk
# engine-dj
# entry
# eobcanka
# eu
# eusamanager
# faxbot
# fightcade
# filemonitor
# finch
# firefly-shimmer
# fleet
# focusrite-control
# focusrite-saffire-mixcontrol
# forkgram-telegram
# fractal-bot
# ftdi-vcp-driver
# fujitsu-scansnap-home
# fx-cast-bridge
# garmin-express
# genesys-cloud
# gitkraken-cli
# gpgfrontend
# grs-bluewallet
# gutenprint
# hdhomerun
# height
# hidock
# hookmark
# hp-easy-start
# html-mangareader
# huiontablet
# hummingbird
# icon-shelf
# iconchamp
# iconchanger
# ideamaker
# imazing-converter
# insta360-studio
# interact-scratchpad
# irpf2023
# jabra-direct
# karafun
# kiibohd-configurator
# konica-minolta-bizhub-c750i-driver
# konica-minolta-bizhub-c759-c658-c368-c287-c3851-driver
# kopiaui
# lasso
# lg-onscreen-control
# linn-konfig
# llamachat
# lo-rain
# logi-options-plus
# logitech-camera-settings
# logitech-g-hub
# logitech-options
# logitune
# lotus
# loupedeck
# macwhisper
# mail-assistant
# mediainfoex
# menubarx
# mfiles
# microsoft-defender
# microsoft-office-businesspro
# microsoft-onenote
# minisim
# mist
# mixin
# mmhmm-studio
# mochi-diffusion
# moneymanager
# monofocus
# morgen
# motu-m-series
# mullvad-browser
# multiviewer-for-f1
# mumu-x
# music-miniplayer
# music-remote
# music-widget
# nanosaur2
# neat
# nordic-nrf-command-line-tools
# northern-softworks-cache-cleaner
# nozbe
# oak9
# obs-advanced-scene-switcher
# obsbot-webcam
# oka-unarchiver
# opal
# openbb-terminal
# openlens
# openrgb
# openrocket
# opensoundmeter
# orbstack
# orcaslicer
# overt
# pallotron-yubiswitch
# paper
# philips-hue-sync
# picfindr
# piclist
# pokemon-tcg-live
# pololu-avr-programmer-v2
# prism
# processmonitor
# prolific-pl2303
# protonmail-import-export
# pulsar
# qflipper
# qmk-toolbox
# quiet-reader
# rapidapi
# readwise-ibooks
# red-canary-mac-monitor
# redquits
# reflex
# reminders-menubar
# restfox
# rewind
# ricoh-theta
# rive
# rode-connect
# rsyncui
# runcat-plugins-manager
# saleae-logic
# samsung-portable-ssd-t7
# scene-maestro
# scenica-player
# scoot
# scrolla
# segger-jlink
# serene
# shureplus-motiv
# silicon-labs-vcp-driver
# simpleclock
# skiff
# slab
# smooze-pro
# sonos
# sony-ps-remote-play
# soulver-cli
# spike
# spotify4bigsur
# spybuster
# starnet-plus-plus
# steelseries-engine
# steelseries-gg
# submariner
# superkey
# superlist
# swift-quit
# synology-cloud-station-backup
# synology-drive
# synology-photo-station-uploader
# synology-surveillance-station-client
# synologyassistant
# tachidesk-sorayomi
# tageditor
# tastytrade
# tea
# teleport-connect
# thangs-sync
# tiptoi-manager
# toshiba-color-mfp
# tsh
# tuist
# ubiquiti-unifi-controller
# uhk-agent
# ulbow
# ultimate-vocal-remover
# unite-phone
# unraid-usb-creator
# usmart-trade
# vbrokers
# vero
# vincelwt-chatgpt
# virtual-desktop-streamer
# vk-calls
# volta
# vpn-by-google-one
# wacom-tablet
# watchfacestudio
# wch-ch34x-usb-serial-driver
# wooshy
# workspace-one-intelligent-hub
# worldpainter
# xtool-creative-space
# yealink-meeting
# youtype
# yubico-authenticator
# yubico-yubikey-manager
# zed
# zsa-wally
# You have 35 outdated formulae installed.
#
# Error: Cannot install under Rosetta 2 in ARM default prefix (/opt/homebrew)!
# To rerun under ARM use:
#     arch -arm64 brew install ...
# To install under x86_64, install Homebrew into /usr/local.
